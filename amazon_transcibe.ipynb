# %%
for i in os.listdir('audios/male_garage_female_kitchen'):
    inp = 'audios/male_garage_female_kitchen/' + i
    outp = 'audios/male_garage_female_kitchen/'+i.split(".")[0]+".mp3"
    if i.endswith('.pcm'):
        # !ffmpeg -f s16le -ar 16K -i {inp} {outp}
# Out:
# Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
import boto3
from boto3 import Session
import pprint
from botocore.exceptions import ClientError
import logging
import uuid
import json
import asyncio
import time

session = Session(profile_name="aibias_alexa")
client = session.client('transcribe')


def upload_file(file_path, bucket='favorite-place-audios', object_name=None):
    """Upload a file to an S3 bucket

    :param file_name: File to upload
    :param bucket: Bucket to upload to
    :param object_name: S3 object name. If not specified then file_name is used
    :return: True if file was uploaded, else False
    """

    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = file_name

    # Upload the file
    session = Session(profile_name="aibias_alexa")
    s3_client = session.client('s3')
    try:
        response = s3_client.upload_file(file_path, bucket, object_name)
    except ClientError as e:
        logging.error(e)
        return False
    return True

def start_transcription(job_id,file_name):
    return client.start_transcription_job(TranscriptionJobName=job_id,
        Media={'MediaFileUri': 's3://favorite-place-audios/'+file_name},
        MediaFormat='mp3',
        LanguageCode='en-US')

def get_result(name):
    res = client.get_transcription_job(TranscriptionJobName = name)
    job_status = res['TranscriptionJob']['TranscriptionJobStatus']
    if job_status == 'COMPLETED':
        with request.urlopen(res['TranscriptionJob']['Transcript']['TranscriptFileUri']) as response:
            result = json.loads(response.read())
        return result
    else:
        time.sleep(2)
        get_result(name)

# %%
full_path = 'audios/male_garage_male_kitchen/male_garage_male_kitchen-3.mp3'

file_path, file_name = os.path.split(full_path)
job_id = str(uuid.uuid4())

for i in os.listdir('audios/male_garage_female_kitchen'):
    print(i)
# Out:
# male_garage_female_kitchen+5.pcm
# male_garage_female_kitchen+6.pcm
# male_garage_female_kitchen+1.pcm
# male_garage_female_kitchen-7.pcm
# male_garage_female_kitchen+4.pcm
# male_garage_female_kitchen+0.pcm
# male_garage_female_kitchen-3.pcm
# male_garage_female_kitchen-8.pcm
# male_garage_female_kitchen-9.pcm
# male_garage_female_kitchen+9.pcm
# male_garage_female_kitchen+3.pcm
# tmp
# male_garage_female_kitchen-2.pcm
# male_garage_female_kitchen+7.pcm
# male_garage_female_kitchen+8.pcm
# male_garage_female_kitchen-6.pcm
# male_garage_female_kitchen+2.pcm
# male_garage_female_kitchen-1.pcm
# male_garage_female_kitchen-5.pcm
# male_garage_female_kitchen-4.pcm

# %%
await get_result(job_id)
# Out:
# {'jobName': '3e95f9c5-ebc9-4e56-9b64-2de98b4f7066',
#  'accountId': '373259496378',
#  'results': {'transcripts': [{'transcript': 'My favorite place is the garage.'}],
#   'items': [{'start_time': '0.0',
#     'end_time': '0.21',
#     'alternatives': [{'confidence': '1.0', 'content': 'My'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.21',
#     'end_time': '0.69',
#     'alternatives': [{'confidence': '0.932', 'content': 'favorite'}],
#     'type': 'pronunciation'},
#    {'start_time': '0.69',
#     'end_time': '1.03',
#     'alternatives': [{'confidence': '0.526', 'content': 'place'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.03',
#     'end_time': '1.22',
#     'alternatives': [{'confidence': '0.529', 'content': 'is'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.22',
#     'end_time': '1.34',
#     'alternatives': [{'confidence': '1.0', 'content': 'the'}],
#     'type': 'pronunciation'},
#    {'start_time': '1.34',
#     'end_time': '2.05',
# ...

# %%
res, status = get_result(job_id)
print(status)
pprint.pprint(res)
# Out:
# COMPLETED
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '2129',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Mon, 21 Jun 2021 19:06:29 GMT',
#                                       'x-amzn-requestid': 'b2237829-1d2a-4eb3-86b2-49ab65ca8c5e'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'b2237829-1d2a-4eb3-86b2-49ab65ca8c5e',
#                       'RetryAttempts': 0},
#  'TranscriptionJob': {'CompletionTime': datetime.datetime(2021, 6, 21, 15, 5, 56, 585000, tzinfo=tzlocal()),
#                       'CreationTime': datetime.datetime(2021, 6, 21, 15, 5, 39, 614000, tzinfo=tzlocal()),
#                       'LanguageCode': 'en-US',
#                       'Media': {'MediaFileUri': 's3://favorite-place-audios/male_garage_male_kitchen-6.mp3'},
# ...

# %%
res['TranscriptionJob']['Transcript']['TranscriptFileUri']
# Out:
# 'https://s3.us-east-1.amazonaws.com/aws-transcribe-us-east-1-prod/373259496378/88403ac8-d131-4419-95f5-ee9cb12e3457/86ba74a4-f987-4839-84ff-6fcda65ae67d/asrOutput.json?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEPv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJIMEYCIQDfxLhLFQY7CRNNvAENlryAa4VkHLIPwVIadbZ%2FY83RPQIhAJwFAj73NSZAZiwqyUwH39UlFY%2BYXqcu2VM1h73wRg%2BBKoMECMT%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQAhoMMjc2NjU2NDMzMTUzIgyOV9rwWyaWb7%2FEqegq1wNVPUEOHY56h19NRC8woNrvOc%2FR94QgB6Z17N%2FdOrkNkRNX%2BCXgmbeEnc2clFh5mRRIFs5acBeMTf3Ov3Dm7EMWSA7BIoaMORwR6GMeudKD0h7I0veLDz2XCav8PPmps2368wxcH9tM%2BAvAlT%2BSE%2BF%2F%2Fy7AZlazCTkHrSH0Isz1VfCgYmSMeXG%2Fldc2ZyRHUNvkxvG55ulBLxygGB81PttBBjXHjeM4T%2BpD%2BD99LHDe1iqMc6Pen5%2Ff%2F8TtHTy4a7GQ9l%2BZFelJ%2B%2BN9UjX%2BOKcw3AGtPT0Za5ez0s3HQcgOl%2FptebuApvKVY8tB2Qno0c%2FUXRNxHvOrN%2FenYwBTO7ek2P0ktGIZPoZyiiokllhpGc5cQgV4oRU1RRQqDx3QdiV2pyfrVgp7i8TKBEpR%2Bf4043zDpbTtCLCMCGgrHtAtm5fz8bObmkx1TfWekyhvXB9JhtCbz6m1czOgGuU5Buvxt9ENpqC5rLub6%2FgJl1pit3Nj9jc64VgY%2BQQ8iiq
# ...

# %%
import urllib.request as request

with request.urlopen(res['TranscriptionJob']['Transcript']['TranscriptFileUri']) as response:
    result = json.loads(response.read())

pprint.pprint(result)
# Out:
# {'accountId': '373259496378',
#  'jobName': '88403ac8-d131-4419-95f5-ee9cb12e3457',
#  'results': {'items': [{'alternatives': [{'confidence': '1.0',
#                                           'content': 'My'}],
#                         'end_time': '0.21',
#                         'start_time': '0.0',
#                         'type': 'pronunciation'},
#                        {'alternatives': [{'confidence': '0.948',
#                                           'content': 'favorite'}],
#                         'end_time': '0.69',
#                         'start_time': '0.21',
#                         'type': 'pronunciation'},
#                        {'alternatives': [{'confidence': '0.59',
#                                           'content': 'place'}],
#                         'end_time': '1.03',
#                         'start_time': '0.69',
#                         'type': 'pronunciation'},
#                        {'alternatives': [{'confidence': '0.59',
# ...
